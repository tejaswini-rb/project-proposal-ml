# %%
from google.colab import drive
import os
import zipfile
from tqdm import tqdm
from sklearn.model_selection import train_test_split
import shutil
# Libraries for do visualization
import matplotlib.image as mpimg
import datetime
import os

# Data handling and numerical operations
import numpy as np
import pandas as pd

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
from keras.preprocessing.image import load_img

# TensorFlow and Keras for deep learning
import tensorflow as tf
from tensorflow.keras import Sequential, regularizers
from tensorflow.keras.layers import (
    Dense, Dropout, BatchNormalization, Conv2D, MaxPooling2D, Flatten,
    GlobalAveragePooling2D, Rescaling, Normalization
)
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.callbacks import Callback, ReduceLROnPlateau, TensorBoard, EarlyStopping
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.regularizers import l2
from tensorflow.keras.backend import clear_session

# Scikit-learn for model evaluation
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split


# Time for calculating training speed
import time

# %%
class DataPreparation:
    def __init__(self, zip_path):
      drive.mount('/content/Drive')
      self.zip_path = zip_path
      self.destination_folder="/content/Dataset/"

    def clear_destination_folder(self,original=True):
        for item in os.listdir(self.destination_folder):
            item_path = os.path.join(self.destination_folder, item)
            if original:
              if os.path.isdir(item_path) and item in ['train', 'val', 'test']:
                continue
              shutil.rmtree(item_path, ignore_errors=True)
            else:
              if os.path.isdir(item_path) and item not in ['train', 'val', 'test']:
                continue
              shutil.rmtree(item_path, ignore_errors=True)

    def extract_zip_file(self):
      with zipfile.ZipFile(self.zip_path, 'r') as zf:
        for member in tqdm(zf.infolist(), desc='Extracting'):
          try:
            zf.extract(member, self.destination_folder)
          except zipfile.error as e:
              print(f"Error extracting {member}: {e}")

    def print_class_counts(self):
      try:
        class_names = sorted(os.listdir(self.destination_folder))
        for class_name in class_names:
          class_path = os.path.join(self.destination_folder, class_name)
          if os.path.isdir(class_path):
            contents = os.listdir(class_path)
            print(f"{class_name}: {len(contents)}")
          else:
            print(f"{class_name} is not a directory.")
      except FileNotFoundError:
        print(f"The path '{self.destination_folder}' does not exist.")

    def split_data(self, test_size=0.2, val_size=0.25):
        self.clear_destination_folder(original=False)
        class_names = [d for d in os.listdir(self.destination_folder) if os.path.isdir(os.path.join(self.destination_folder, d))]

        for split in ['train', 'val', 'test']:
            os.makedirs(os.path.join(self.destination_folder, split), exist_ok=True)
            for class_name in class_names:
                os.makedirs(os.path.join(self.destination_folder, split, class_name), exist_ok=True)

        for class_name in class_names:
            class_path = os.path.join(self.destination_folder, class_name)
            files = [f for f in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, f))]

            if not files:
                continue

            # Split files into training+validation and test sets
            train_val_files, test_files = train_test_split(files, test_size=test_size, random_state=42)

            # split training+validation files into training and validation sets
            train_files, val_files = train_test_split(train_val_files, test_size=val_size / (1 - test_size), random_state=42)

            # Move files to their new respective directories
            for file in train_files:
                shutil.move(os.path.join(class_path, file), os.path.join(self.destination_folder, 'train', class_name, file))
            for file in val_files:
                shutil.move(os.path.join(class_path, file), os.path.join(self.destination_folder, 'val', class_name, file))
            for file in test_files:
                shutil.move(os.path.join(class_path, file), os.path.join(self.destination_folder, 'test', class_name, file))

            print(f"Processed {class_name}: Train files: {len(train_files)}, Validation files: {len(val_files)}, Test files: {len(test_files)}")
        self.clear_destination_folder()

# %%
destination_folder="/content/Dataset/"
train_dir=os.path.join(destination_folder, 'train')
val_dir=os.path.join(destination_folder, 'val')
test_dir=os.path.join(destination_folder, 'test')

# %%
zip_path = '/content/Drive/MyDrive/fruit_data.zip'
data_preprocessor = DataPreparation(zip_path)
data_preprocessor.extract_zip_file()
data_preprocessor.print_class_counts()
data_preprocessor.split_data(test_size=0.15,val_size=0.2)
# Out:
# Drive already mounted at /content/Drive; to attempt to forcibly remount, call drive.mount("/content/Drive", force_remount=True).
# Extracting: 100%|██████████| 1655/1655 [00:00<00:00, 5358.15it/s]
# fresh_peaches_done: 250
# fresh_pomegranates_done: 311
# fresh_strawberries_done: 250
# rotten_peaches_done: 343
# rotten_pomegranates_done: 250
# rotten_strawberries_done: 251
# test: 6
# train: 6
# val: 6
# Processed rotten_pomegranates_done: Train files: 162, Validation files: 50, Test files: 38
# Processed rotten_strawberries_done: Train files: 162, Validation files: 51, Test files: 38
# Processed fresh_peaches_done: Train files: 162, Validation files: 50, Test files: 38
# Processed rotten_peaches_done: Train files: 222, Validation files: 69, Test files: 52
# Processed fresh_strawberries_done: Train files: 162, Validation files: 50, Test files: 38
# Processed fresh_pomegranates_done: Train files: 201, Validation files: 63, Test files: 47

# %%
train_dir = '/content/Dataset/train/'

fig, axs = plt.subplots(2, 3, figsize=(10, 7))
axs = axs.ravel()

for i, class_dir in enumerate(os.listdir(train_dir)):
    class_dir_path = os.path.join(train_dir, class_dir)

    if os.path.isdir(class_dir_path):
        files = os.listdir(class_dir_path)

        images = [file for file in files if file.lower().endswith(('.png', '.jpg', '.jpeg'))]
        first_image_path = os.path.join(class_dir_path, images[0])

        img = load_img(first_image_path)
        axs[i].imshow(img)
        axs[i].set_title(class_dir)
        if i == 5:
          break

plt.tight_layout()
plt.show()

# %%
def generators(train_dir,val_dir,test_dir):
      train_datagen = ImageDataGenerator(rescale=1./255,
                                         rotation_range=30,
                                         brightness_range=[0.8,1.2],
                                         shear_range=0.1,
                                         zoom_range=0.1,
                                         fill_mode='nearest',
                                         horizontal_flip=True,
                                         vertical_flip=True)

      train_generator = train_datagen.flow_from_directory(directory=train_dir,
                                                          target_size=(300, 300),
                                                          color_mode='rgb',
                                                          class_mode='sparse',
                                                          batch_size=32,
                                                          shuffle=True,
                                                          seed=127,
                                                          subset='training',
                                                          interpolation='nearest',
                                                          keep_aspect_ratio=False)

      validation_datagen = ImageDataGenerator(rescale=1./255)
      validation_generator = validation_datagen.flow_from_directory(directory=val_dir,
                                                                batch_size=32,
                                                                class_mode = 'sparse',
                                                                target_size=(300, 300),
                                                                shuffle=False)
      test_datagen = ImageDataGenerator(rescale=1./255)
      test_generator = validation_datagen.flow_from_directory(directory=test_dir,
                                                                batch_size=32,
                                                                class_mode = 'sparse',
                                                                target_size=(300, 300),
                                                                shuffle=False)
      return train_generator, validation_generator,test_generator
train_generator, validation_generator,test_generator=generators(train_dir,val_dir,test_dir)
# Out:
# Found 1071 images belonging to 6 classes.
# Found 333 images belonging to 6 classes.
# Found 251 images belonging to 6 classes.

# %%
# Get a batch of images
x_batch, y_batch = next(train_generator)

# Plot the images
plt.figure(figsize=(20, 10))
for i in range(8):  # Display the first 10 images from the batch
    plt.subplot(2, 5, i+1)
    plt.imshow(x_batch[i])
    plt.axis('off')  # Optional: Remove axis
plt.show()

# %%
#CNN MODEL
model=Sequential()

# model.add(Rescaling(1./255, ))

img_height=300
img_width=300
batch_size=8
model.add(Conv2D(32,kernel_size=(3,3),activation='relu',padding='valid',input_shape=(img_height, img_width, 3)))
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))
model.add(BatchNormalization())

model.add(Conv2D(64,kernel_size=(3,3),activation='relu',padding='valid'))
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))
model.add(BatchNormalization())


model.add(Conv2D(128,kernel_size=(3,3),activation='relu',padding='valid'))
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))
model.add(BatchNormalization())

model.add(Conv2D(128,kernel_size=(3,3),activation='relu',padding='valid'))
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))
model.add(BatchNormalization())

model.add(Conv2D(64,kernel_size=(3,3),activation='relu',padding='valid'))
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))
model.add(BatchNormalization())

model.add(Conv2D(32,kernel_size=(3,3),activation='relu',padding='valid'))
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))
model.add(BatchNormalization())

model.add(Flatten())

model.add(Dense(32,activation='relu',kernel_regularizer=tf.keras.regularizers.L1L2(l1=1e-3, l2=1e-3),))
model.add(Dropout(0.2))
model.add(Dense(64,activation='relu',kernel_regularizer=tf.keras.regularizers.L1L2(l1=1e-3, l2=1e-3)))
model.add(Dropout(0.1))
model.add(Dense(128,activation='relu',kernel_regularizer=tf.keras.regularizers.L1L2(l1=1e-3, l2=1e-3)))
model.add(Dropout(0.2))
model.add(Dense(64,activation='relu',kernel_regularizer=tf.keras.regularizers.L1L2(l1=1e-3, l2=1e-3)))
model.add(Dropout(0.1))
model.add(Dense(32,activation='relu',kernel_regularizer=tf.keras.regularizers.L1L2(l1=1e-3, l2=1e-3)))

model.add(Dense(6,activation='softmax',kernel_regularizer=tf.keras.regularizers.L1L2(l1=1e-3, l2=1e-3)))

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.6e-3),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy', tf.keras.metrics.SparseTopKCategoricalAccuracy(k=2)]) #top 2 accuracy

start_time = time.time()
history = model.fit(train_generator,
                    epochs=50,
                    validation_data=validation_generator)
end_time = time.time()

speed = (end_time - start_time) / 50 # num of epochs

print("Speed: " + str(speed) + " seconds per epoch")
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5727: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 34/34 [==============================] - 46s 959ms/step - loss: 4.3712 - accuracy: 0.2260 - sparse_top_k_categorical_accuracy: 0.4202 - val_loss: 4.3058 - val_accuracy: 0.2072 - val_sparse_top_k_categorical_accuracy: 0.3814
# Epoch 2/50
# 34/34 [==============================] - 30s 892ms/step - loss: 3.9965 - accuracy: 0.3735 - sparse_top_k_categorical_accuracy: 0.5882 - val_loss: 4.1385 - val_accuracy: 0.2072 - val_sparse_top_k_categorical_accuracy: 0.3574
# Epoch 3/50
# 34/34 [==============================] - 29s 846ms/step - loss: 3.6084 - accuracy: 0.4762 - sparse_top_k_categorical_accuracy: 0.7218 - val_loss: 4.0511 - val_accuracy: 0.2102 - val_sparse_top_k_categorical_accuracy: 0.3574
# Epoch 4/50
# 34/34 [==============================] - 29s 846ms/step - loss: 3.2633 - accuracy: 0.5584 - sparse_top_k_categorical_accuracy: 0.7983 - val_loss: 4.0408 - val_accuracy: 0.2132 - val_sparse_top_k_categorical_accuracy: 0.3964
# Epoch 5/50
# 34/34 [==============================] - 29s 845ms/step - loss: 3.1226 - accuracy: 0.5472 - sparse_top_k_categorical_accuracy: 0.8235 - val_loss: 3.7388 - val_accuracy: 0.2973 - val_sparse_top_k_categorical_accuracy: 0.4625
# Epoch 6/50
# 34/34 [==============================] - 29s 845ms/step - loss: 2.9619 - accuracy: 0.5836 - sparse_top_k_categorical_accuracy: 0.8226 - val_loss: 3.7365 - val_accuracy: 0.3694 - val_sparse_top_k_categorical_accuracy: 0.5526
# Epoch 7/50
# 34/34 [==============================] - 29s 845ms/step - loss: 2.8141 - accuracy: 0.6032 - sparse_top_k_categorical_accuracy: 0.8497 - val_loss: 3.7211 - val_accuracy: 0.3994 - val_sparse_top_k_categorical_accuracy: 0.5736
# Epoch 8/50
# 34/34 [==============================] - 29s 845ms/step - loss: 2.6395 - accuracy: 0.6387 - sparse_top_k_categorical_accuracy: 0.8590 - val_loss: 3.6693 - val_accuracy: 0.3904 - val_sparse_top_k_categorical_accuracy: 0.5375
# Epoch 9/50
# 34/34 [==============================] - 28s 838ms/step - loss: 2.5307 - accuracy: 0.6396 - sparse_top_k_categorical_accuracy: 0.8627 - val_loss: 3.4477 - val_accuracy: 0.3393 - val_sparse_top_k_categorical_accuracy: 0.5586
# Epoch 10/50
# 34/34 [==============================] - 30s 886ms/step - loss: 2.4130 - accuracy: 0.6639 - sparse_top_k_categorical_accuracy: 0.8730 - val_loss: 3.6416 - val_accuracy: 0.2883 - val_sparse_top_k_categorical_accuracy: 0.5375
# Epoch 11/50
# 34/34 [==============================] - 30s 871ms/step - loss: 2.4136 - accuracy: 0.6461 - sparse_top_k_categorical_accuracy: 0.8683 - val_loss: 3.2600 - val_accuracy: 0.3754 - val_sparse_top_k_categorical_accuracy: 0.5886
# Epoch 12/50
# 34/34 [==============================] - 29s 851ms/step - loss: 2.3056 - accuracy: 0.6564 - sparse_top_k_categorical_accuracy: 0.8796 - val_loss: 3.8264 - val_accuracy: 0.3003 - val_sparse_top_k_categorical_accuracy: 0.5586
# Epoch 13/50
# 34/34 [==============================] - 29s 846ms/step - loss: 2.2044 - accuracy: 0.6695 - sparse_top_k_categorical_accuracy: 0.8880 - val_loss: 3.3294 - val_accuracy: 0.3303 - val_sparse_top_k_categorical_accuracy: 0.5736
# Epoch 14/50
# 34/34 [==============================] - 29s 852ms/step - loss: 2.0940 - accuracy: 0.6965 - sparse_top_k_categorical_accuracy: 0.9066 - val_loss: 3.3378 - val_accuracy: 0.3874 - val_sparse_top_k_categorical_accuracy: 0.5526
# Epoch 15/50
# 34/34 [==============================] - 29s 846ms/step - loss: 2.0457 - accuracy: 0.6872 - sparse_top_k_categorical_accuracy: 0.9020 - val_loss: 3.1955 - val_accuracy: 0.3483 - val_sparse_top_k_categorical_accuracy: 0.6486
# Epoch 16/50
# 34/34 [==============================] - 30s 869ms/step - loss: 1.9875 - accuracy: 0.6900 - sparse_top_k_categorical_accuracy: 0.9066 - val_loss: 2.6650 - val_accuracy: 0.4655 - val_sparse_top_k_categorical_accuracy: 0.7057
# Epoch 17/50
# 34/34 [==============================] - 30s 877ms/step - loss: 1.9264 - accuracy: 0.7087 - sparse_top_k_categorical_accuracy: 0.9104 - val_loss: 2.5419 - val_accuracy: 0.5165 - val_sparse_top_k_categorical_accuracy: 0.6967
# Epoch 18/50
# 34/34 [==============================] - 29s 848ms/step - loss: 1.8679 - accuracy: 0.7152 - sparse_top_k_categorical_accuracy: 0.9225 - val_loss: 2.0767 - val_accuracy: 0.6186 - val_sparse_top_k_categorical_accuracy: 0.8769
# Epoch 19/50
# 34/34 [==============================] - 29s 846ms/step - loss: 1.8166 - accuracy: 0.6975 - sparse_top_k_categorical_accuracy: 0.9066 - val_loss: 1.7547 - val_accuracy: 0.7267 - val_sparse_top_k_categorical_accuracy: 0.9249
# Epoch 20/50
# 34/34 [==============================] - 29s 861ms/step - loss: 1.8046 - accuracy: 0.7171 - sparse_top_k_categorical_accuracy: 0.9057 - val_loss: 1.7960 - val_accuracy: 0.7087 - val_sparse_top_k_categorical_accuracy: 0.8919
# Epoch 21/50
# 34/34 [==============================] - 29s 850ms/step - loss: 1.7332 - accuracy: 0.7190 - sparse_top_k_categorical_accuracy: 0.9206 - val_loss: 2.1730 - val_accuracy: 0.6036 - val_sparse_top_k_categorical_accuracy: 0.7568
# Epoch 22/50
# 34/34 [==============================] - 29s 843ms/step - loss: 1.6726 - accuracy: 0.7367 - sparse_top_k_categorical_accuracy: 0.9206 - val_loss: 1.7096 - val_accuracy: 0.7297 - val_sparse_top_k_categorical_accuracy: 0.9009
# Epoch 23/50
# 34/34 [==============================] - 29s 845ms/step - loss: 1.6626 - accuracy: 0.7414 - sparse_top_k_categorical_accuracy: 0.9206 - val_loss: 1.6350 - val_accuracy: 0.7267 - val_sparse_top_k_categorical_accuracy: 0.9279
# Epoch 24/50
# 34/34 [==============================] - 29s 851ms/step - loss: 1.6293 - accuracy: 0.7292 - sparse_top_k_categorical_accuracy: 0.9290 - val_loss: 1.7641 - val_accuracy: 0.6877 - val_sparse_top_k_categorical_accuracy: 0.8559
# Epoch 25/50
# 34/34 [==============================] - 30s 893ms/step - loss: 1.5846 - accuracy: 0.7516 - sparse_top_k_categorical_accuracy: 0.9244 - val_loss: 1.7154 - val_accuracy: 0.6847 - val_sparse_top_k_categorical_accuracy: 0.9159
# Epoch 26/50
# 34/34 [==============================] - 30s 867ms/step - loss: 1.5656 - accuracy: 0.7479 - sparse_top_k_categorical_accuracy: 0.9281 - val_loss: 1.6937 - val_accuracy: 0.6907 - val_sparse_top_k_categorical_accuracy: 0.8829
# Epoch 27/50
# 34/34 [==============================] - 29s 843ms/step - loss: 1.5465 - accuracy: 0.7348 - sparse_top_k_categorical_accuracy: 0.9216 - val_loss: 1.9443 - val_accuracy: 0.6276 - val_sparse_top_k_categorical_accuracy: 0.8018
# Epoch 28/50
# 34/34 [==============================] - 29s 839ms/step - loss: 1.4587 - accuracy: 0.7600 - sparse_top_k_categorical_accuracy: 0.9374 - val_loss: 1.5679 - val_accuracy: 0.7417 - val_sparse_top_k_categorical_accuracy: 0.9039
# Epoch 29/50
# 34/34 [==============================] - 29s 840ms/step - loss: 1.5400 - accuracy: 0.7311 - sparse_top_k_categorical_accuracy: 0.9132 - val_loss: 1.4594 - val_accuracy: 0.7598 - val_sparse_top_k_categorical_accuracy: 0.9249
# Epoch 30/50
# 34/34 [==============================] - 29s 846ms/step - loss: 1.3892 - accuracy: 0.7815 - sparse_top_k_categorical_accuracy: 0.9449 - val_loss: 2.4264 - val_accuracy: 0.5105 - val_sparse_top_k_categorical_accuracy: 0.7177
# Epoch 31/50
# 34/34 [==============================] - 31s 910ms/step - loss: 1.4057 - accuracy: 0.7750 - sparse_top_k_categorical_accuracy: 0.9374 - val_loss: 1.4443 - val_accuracy: 0.7538 - val_sparse_top_k_categorical_accuracy: 0.9039
# Epoch 32/50
# 34/34 [==============================] - 31s 911ms/step - loss: 1.3425 - accuracy: 0.8039 - sparse_top_k_categorical_accuracy: 0.9505 - val_loss: 1.7941 - val_accuracy: 0.6517 - val_sparse_top_k_categorical_accuracy: 0.8679
# Epoch 33/50
# 34/34 [==============================] - 29s 859ms/step - loss: 1.3543 - accuracy: 0.7768 - sparse_top_k_categorical_accuracy: 0.9430 - val_loss: 1.3873 - val_accuracy: 0.7658 - val_sparse_top_k_categorical_accuracy: 0.9219
# Epoch 34/50
# 34/34 [==============================] - 29s 854ms/step - loss: 1.3709 - accuracy: 0.7703 - sparse_top_k_categorical_accuracy: 0.9253 - val_loss: 1.8265 - val_accuracy: 0.5856 - val_sparse_top_k_categorical_accuracy: 0.8529
# Epoch 35/50
# 34/34 [==============================] - 29s 863ms/step - loss: 1.3259 - accuracy: 0.7768 - sparse_top_k_categorical_accuracy: 0.9374 - val_loss: 1.2515 - val_accuracy: 0.8138 - val_sparse_top_k_categorical_accuracy: 0.9369
# Epoch 36/50
# 34/34 [==============================] - 30s 863ms/step - loss: 1.2369 - accuracy: 0.8151 - sparse_top_k_categorical_accuracy: 0.9570 - val_loss: 1.4408 - val_accuracy: 0.7237 - val_sparse_top_k_categorical_accuracy: 0.8949
# Epoch 37/50
# 34/34 [==============================] - 29s 856ms/step - loss: 1.3088 - accuracy: 0.7740 - sparse_top_k_categorical_accuracy: 0.9402 - val_loss: 1.8763 - val_accuracy: 0.6126 - val_sparse_top_k_categorical_accuracy: 0.7898
# Epoch 38/50
# 34/34 [==============================] - 29s 839ms/step - loss: 1.2762 - accuracy: 0.7843 - sparse_top_k_categorical_accuracy: 0.9412 - val_loss: 1.3685 - val_accuracy: 0.7658 - val_sparse_top_k_categorical_accuracy: 0.8919
# Epoch 39/50
# 34/34 [==============================] - 29s 854ms/step - loss: 1.2034 - accuracy: 0.8086 - sparse_top_k_categorical_accuracy: 0.9533 - val_loss: 1.3022 - val_accuracy: 0.7898 - val_sparse_top_k_categorical_accuracy: 0.9159
# Epoch 40/50
# 34/34 [==============================] - 30s 885ms/step - loss: 1.2618 - accuracy: 0.7806 - sparse_top_k_categorical_accuracy: 0.9412 - val_loss: 1.4913 - val_accuracy: 0.6937 - val_sparse_top_k_categorical_accuracy: 0.8649
# Epoch 41/50
# 34/34 [==============================] - 30s 862ms/step - loss: 1.1968 - accuracy: 0.7974 - sparse_top_k_categorical_accuracy: 0.9514 - val_loss: 1.7928 - val_accuracy: 0.6276 - val_sparse_top_k_categorical_accuracy: 0.7898
# Epoch 42/50
# 34/34 [==============================] - 29s 853ms/step - loss: 1.1778 - accuracy: 0.8039 - sparse_top_k_categorical_accuracy: 0.9496 - val_loss: 1.6567 - val_accuracy: 0.6426 - val_sparse_top_k_categorical_accuracy: 0.8769
# Epoch 43/50
# 34/34 [==============================] - 29s 844ms/step - loss: 1.1551 - accuracy: 0.8030 - sparse_top_k_categorical_accuracy: 0.9468 - val_loss: 1.1980 - val_accuracy: 0.7928 - val_sparse_top_k_categorical_accuracy: 0.9339
# Epoch 44/50
# 34/34 [==============================] - 28s 836ms/step - loss: 1.0932 - accuracy: 0.8338 - sparse_top_k_categorical_accuracy: 0.9608 - val_loss: 1.2107 - val_accuracy: 0.8138 - val_sparse_top_k_categorical_accuracy: 0.9309
# Epoch 45/50
# 34/34 [==============================] - 31s 919ms/step - loss: 1.1075 - accuracy: 0.8077 - sparse_top_k_categorical_accuracy: 0.9570 - val_loss: 1.1844 - val_accuracy: 0.7808 - val_sparse_top_k_categorical_accuracy: 0.9339
# Epoch 46/50
# 34/34 [==============================] - 30s 868ms/step - loss: 1.1067 - accuracy: 0.8226 - sparse_top_k_categorical_accuracy: 0.9580 - val_loss: 1.4475 - val_accuracy: 0.6637 - val_sparse_top_k_categorical_accuracy: 0.8949
# Epoch 47/50
# 34/34 [==============================] - 29s 841ms/step - loss: 1.1521 - accuracy: 0.8058 - sparse_top_k_categorical_accuracy: 0.9468 - val_loss: 1.8677 - val_accuracy: 0.5706 - val_sparse_top_k_categorical_accuracy: 0.8138
# Epoch 48/50
# 34/34 [==============================] - 29s 845ms/step - loss: 1.0812 - accuracy: 0.8207 - sparse_top_k_categorical_accuracy: 0.9627 - val_loss: 1.3403 - val_accuracy: 0.7477 - val_sparse_top_k_categorical_accuracy: 0.8889
# Epoch 49/50
# 34/34 [==============================] - 29s 845ms/step - loss: 1.0494 - accuracy: 0.8329 - sparse_top_k_categorical_accuracy: 0.9636 - val_loss: 1.3439 - val_accuracy: 0.7387 - val_sparse_top_k_categorical_accuracy: 0.8979
# Epoch 50/50
# 34/34 [==============================] - 29s 853ms/step - loss: 1.0482 - accuracy: 0.8282 - sparse_top_k_categorical_accuracy: 0.9627 - val_loss: 1.5349 - val_accuracy: 0.6667 - val_sparse_top_k_categorical_accuracy: 0.8408
# Speed: 33.06381392478943 seconds per epoch

# %%
# Training and Validation Accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Training and Validation Loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))


base_model.trainable = False
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(6, activation='softmax')(x)

model1 = Model(inputs=base_model.input, outputs=predictions)

model1.compile(optimizer=tf.keras.optimizers.Adam(),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy', tf.keras.metrics.SparseTopKCategoricalAccuracy(k=2)]) #top 2 accuracy)

start_time = time.time()
history = model1.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=10
)

end_time = time.time()
speed = (end_time - start_time) / 10 # num of epochs
print("Speed: " + str(speed) + " seconds per epoch")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step
# Epoch 1/10
# 34/34 [==============================] - 35s 883ms/step - loss: 0.7222 - accuracy: 0.7264 - sparse_top_k_categorical_accuracy: 0.8861 - val_loss: 0.3485 - val_accuracy: 0.8529 - val_sparse_top_k_categorical_accuracy: 0.9790
# Epoch 2/10
# 34/34 [==============================] - 28s 830ms/step - loss: 0.3318 - accuracy: 0.8889 - sparse_top_k_categorical_accuracy: 0.9785 - val_loss: 0.3023 - val_accuracy: 0.9009 - val_sparse_top_k_categorical_accuracy: 0.9790
# Epoch 3/10
# 34/34 [==============================] - 28s 827ms/step - loss: 0.2539 - accuracy: 0.9113 - sparse_top_k_categorical_accuracy: 0.9907 - val_loss: 0.3459 - val_accuracy: 0.8649 - val_sparse_top_k_categorical_accuracy: 0.9790
# Epoch 4/10
# 34/34 [==============================] - 30s 875ms/step - loss: 0.1509 - accuracy: 0.9449 - sparse_top_k_categorical_accuracy: 0.9963 - val_loss: 0.2641 - val_accuracy: 0.8979 - val_sparse_top_k_categorical_accuracy: 0.9910
# Epoch 5/10
# 34/34 [==============================] - 28s 832ms/step - loss: 0.1732 - accuracy: 0.9318 - sparse_top_k_categorical_accuracy: 0.9907 - val_loss: 0.2914 - val_accuracy: 0.8919 - val_sparse_top_k_categorical_accuracy: 0.9880
# Epoch 6/10
# 34/34 [==============================] - 28s 828ms/step - loss: 0.1650 - accuracy: 0.9365 - sparse_top_k_categorical_accuracy: 0.9935 - val_loss: 0.2704 - val_accuracy: 0.9219 - val_sparse_top_k_categorical_accuracy: 0.9700
# Epoch 7/10
# 34/34 [==============================] - 30s 878ms/step - loss: 0.1326 - accuracy: 0.9505 - sparse_top_k_categorical_accuracy: 0.9953 - val_loss: 0.2287 - val_accuracy: 0.9399 - val_sparse_top_k_categorical_accuracy: 0.9820
# Epoch 8/10
# 34/34 [==============================] - 29s 843ms/step - loss: 0.1009 - accuracy: 0.9636 - sparse_top_k_categorical_accuracy: 0.9991 - val_loss: 0.1868 - val_accuracy: 0.9369 - val_sparse_top_k_categorical_accuracy: 0.9910
# Epoch 9/10
# 34/34 [==============================] - 30s 862ms/step - loss: 0.1025 - accuracy: 0.9561 - sparse_top_k_categorical_accuracy: 0.9963 - val_loss: 0.1695 - val_accuracy: 0.9489 - val_sparse_top_k_categorical_accuracy: 0.9880
# Epoch 10/10
# 34/34 [==============================] - 29s 846ms/step - loss: 0.0756 - accuracy: 0.9711 - sparse_top_k_categorical_accuracy: 0.9991 - val_loss: 0.2196 - val_accuracy: 0.9339 - val_sparse_top_k_categorical_accuracy: 0.9760
# Speed: 31.991165018081666 seconds per epoch

# %%
# Training and Validation Accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Training and Validation Loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
